# %%
import numpy as np

# %%
import pandas as pd

# %%
a=[10,20,30]

# %%
b=['a','b','c']

# %%
c={'a':10,'b':20,'c':30}

# %%
pd.Series(data=a)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=a,index=b)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(a,b)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
c
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(c)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(c,b)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=[print])
# Out:
# 0    <built-in function print>
# dtype: object

# %%
a=pd.Series([1,2,3,4],[0,1,2,3])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
a[1]
# Out:
# 2

# %%
b=pd.Series([1,2,3,5],[0,1,3,4])

# %%
b
# Out:
# 0    1
# 1    2
# 3    3
# 4    5
# dtype: int64

# %%
a+b
# Out:
# 0    2.0
# 1    4.0
# 2    NaN
# 3    7.0
# 4    NaN
# dtype: float64

# %%
np.linspace(0,1,3)
# Out:
# array([0. , 0.5, 1. ])
